# %% [markdown]
# <a href="https://colab.research.google.com/github/yk-Jeong/KNOU/blob/main/2022_python/%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%8A%A4%ED%84%B0%EB%94%94_22%EC%A3%BC%EC%B0%A8(220928).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 지난 시간에는 아파서 결석

# %% [markdown]
# ##1. 객체와 클래스, 인스턴스
#
# 객체, 클래스, 인스턴스를 구분할 수 있어야 한다.
# - 속성: 변수, cpp의 데이터 멤버

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 예제 1.
# 다음과 같이 출력해보자.
# <pre>
# 이름     총점     평균
# 윤인성   368      92.0
# 연하진   384
# ...</pre>

# %% [markdown]
# 원래 방식이라면...

# %%
# 학생 리스트를 dict로 선언

students = [{"name":"윤인성", "korean":87, "math":98, "english":88, "science":95},
            {"name":"연하진", "korean":92, "math":98, "english":96, "science":98},
            {"name":"구지연", "korean":76, "math":96, "english":94, "science":90},
            {"name":"나선주", "korean":98, "math":92, "english":96, "science":92},
            {"name":"윤아린", "korean":95, "math":98, "english":98, "science":98},
            {"name":"김명월", "korean":64, "math":88, "english":92, "science":92}]

# %%
print("이름  총점  평균")
for student in students : 
  score_sum = student['korean']+student['math']+student['english']+student['science']
  avg = score_sum / 4
  print(student["name"], score_sum, avg)
# Out:
# 이름  총점  평균
# 윤인성 368 92.0
# 연하진 384 96.0
# 구지연 356 89.0
# 나선주 378 94.5
# 윤아린 389 97.25
# 김명월 336 84.0

# %% [markdown]
# 함수를 정의해 같은 결과를 출력하고자 한다면?

# %%
def create_student(name, korean, math, english, science):
  return {
      "name":name, "korean" : korean, "math": math, "english": english, "science":science
  }

# %%
students = [
    create_student("윤인성", 87, 98, 88, 95),
    create_student("연하진", 92, 98, 96, 98),
    create_student("구지연", 76, 96, 94, 90),
    create_student("나선주", 98, 92, 96, 92),
    create_student("윤아린", 95, 98, 98, 98),
    create_student("김명월", 64, 88, 92, 92)
]

# %%
# 숙제: 함수로 만들기 
# 학생들의 총점과 평균을 출력해 보자. 

# 1. 합계 구하는 함수 
# 2. 평균 구하는 함수
# 3. 출력하는 함수 

students_to_string()
# Out:
# [{'name': '윤인성', 'korean': 87, 'math': 98, 'english': 88, 'science': 95},
#  {'name': '연하진', 'korean': 92, 'math': 98, 'english': 96, 'science': 98},
#  {'name': '구지연', 'korean': 76, 'math': 96, 'english': 94, 'science': 90},
#  {'name': '나선주', 'korean': 98, 'math': 92, 'english': 96, 'science': 92},
#  {'name': '윤아린', 'korean': 95, 'math': 98, 'english': 98, 'science': 98},
#  {'name': '김명월', 'korean': 64, 'math': 88, 'english': 92, 'science': 92}]

# %%
print
for student in students:
  print(student_to_string(student))
